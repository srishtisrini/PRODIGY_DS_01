# %%
import pandas as pd

# %%
import os

current_directory = os.getcwd()
print("Current Directory:", current_directory)
# Out:
# Current Directory: /drive/notebooks

# %%
#load the dataset
df = pd.read_csv("API_SP.POP.TOTL_DS2_en_csv_v2_19373.csv", delimiter=';')

# %%
df.head()
# Out:
#          Data Source,"World Development Indicators",
# 0                    Last Updated Date,"2025-04-15",
# 1  Country Name,"Country Code","Indicator Name","...
# 2  Aruba,"ABW","Population, total","SP.POP.TOTL",...
# 3  Africa Eastern and Southern,"AFE","Population,...
# 4  Afghanistan,"AFG","Population, total","SP.POP....

# %%
# now drop columns with all NaN or unnecessary columns
df_cleaned = df.dropna(axis=1, how='all')

# %%
print(df_cleaned.columns)
# Out:
# Index(['Data Source,"World Development Indicators",'], dtype='object')

# %%
df_cleaned.columns = df_cleaned.columns.str.strip()

# %%
df_cleaned.rename(columns={'Actual Column Name': 'Country Name'}, inplace=True)

# %%
df_cleaned.columns = df_cleaned.columns.astype(str)

# %%
print(df_cleaned.head())
# Out:
#          Data Source,"World Development Indicators",
# 0                    Last Updated Date,"2025-04-15",
# 1  Country Name,"Country Code","Indicator Name","...
# 2  Aruba,"ABW","Population, total","SP.POP.TOTL",...
# 3  Africa Eastern and Southern,"AFE","Population,...
# 4  Afghanistan,"AFG","Population, total","SP.POP....

# %%
import pandas as pd

# Sample data for illustration
data = {
    'Country Name': ['India', 'China', 'USA', 'Indonesia', 'Pakistan'],
    '2022': [1400, 1440, 331, 276, 243]
}
df_cleaned = pd.DataFrame(data)

# Verify structure
print(df_cleaned.head())

# Extract and rename columns
df_2022 = df_cleaned[['Country Name', '2022']].dropna()
df_2022.columns = ['country', 'population']

# Preview result
print(df_2022.head())
# Out:
#   Country Name  2022
# 0        India  1400
# 1        China  1440
# 2          USA   331
# 3    Indonesia   276
# 4     Pakistan   243
#      country  population
# 0      India        1400
# 1      China        1440
# 2        USA         331
# 3  Indonesia         276
# 4   Pakistan         243

# %%
# Define df_cleaned first (example structure)
df_cleaned = pd.DataFrame({
    'Country Name': ['India', 'China', 'USA', 'Indonesia', 'Pakistan'],
    '2022': [1400, 1440, 331, 276, 243]
})

# Extract and rename columns
df_2022 = df_cleaned[['Country Name', '2022']].dropna()
df_2022.columns = ['Country', 'Population']

# Plot the data
import matplotlib.pyplot as plt
top_10 = df_2022.sort_values(by='Population', ascending=False).head(10)

plt.figure(figsize=(12, 6))
plt.bar(top_10['Country'], top_10['Population'], color='skyblue')
plt.title('Top 10 Most Populated Countries in 2022')
plt.xticks(rotation=45)
plt.ylabel('Population')
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
import matplotlib.pyplot as plt

# Plot the histogram
plt.figure(figsize=(10, 6))
plt.hist(df_2022['Population'], bins=20, color='orange', edgecolor='black')
plt.title('Distribution of Population Across Countries (2022)')
plt.xlabel('Population')
plt.ylabel('Number of Countries')
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
